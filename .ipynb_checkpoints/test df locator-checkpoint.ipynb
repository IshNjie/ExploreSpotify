# %% [markdown]
# https://developer.spotify.com/console/get-playlist-tracks/?playlist_id=&market=&fields=&limit=&offset=&additional_types=
#
# https://developer.spotify.com/console/get-current-user-playlists/?limit=&offset=

# %%
import requests
import pandas as pd
from spot_secrets import *

# %%
def getPlaylists(playEndpoint,authToken):
    token_headers = {'Authorization':f"Bearer {authToken}"}
    auth_response = requests.get(playEndpoint,headers = token_headers)
    print('Status Code: ' + str(auth_response.status_code))
    auth_response_data = auth_response.json()
    print('Number of Playlists: '+ str(len(auth_response_data['items'])))
    
    playlists = []
    playlist_owner = []
    playlist_id = []

    for i in range(len(auth_response_data['items'])):
        playlists.append(auth_response_data['items'][i]['name'])
        playlist_owner.append(auth_response_data['items'][i]['owner']['id'])
        playlist_id.append(auth_response_data['items'][i]['id'])
    
    d = {'id':playlist_id, 'playlists':playlists,'owner':playlist_owner}
    df = pd.DataFrame(data = d)
    # hides actual names of owners
    df['owner'] = df['owner'].astype('category').cat.codes
    
    return df

# %%
listPlay = getPlaylists(playlist_endpoint,playlist_OAuth)
# Out:
# Status Code: 200
# Number of Playlists: 17

# %%
listPlay
# Out:
#                         id            playlists  owner
# 0   0tO5lF6PPlxWqrgOtkjGSj        Time to party      1
# 1   37i9dQZF1EUMDoJuT8yJsl  Your Top Songs 2021      2
# 2   2jWONoEBSzcpi2xICOAOn4           Top Breezy      0
# 3   3OzK4uxf4XZDfgVNvCchb0               Breezy      0
# 4   1L96hxZel4WA3xwJCvmOHr                  5x5      0
# 5   7DusX2liW1lemQzgjMGy2N                   MJ      0
# 6   0jg5h3GThzjL5Behr1OxC7                   JT      0
# 7   5ckYyTjv0aVDnQ53Yqfy5U                Turnt      0
# 8   5D9yjaZikw2Eg10SrHUC9f               Clouds      0
# 9   3bGG6RwxOpyNvIsUMfv8wL                  R&B      0
# 10  7izjorDl1q4jOBGNmi1yCO         RnB OldSkool      0
# 11  1lDKFQiFotNEuWHlO7NEZX             US Smoke      0
# 12  5hdjoZ5vhNGb09Feuw2wsA                Skeng      0
# 13  6VUgH8TkjQ2T2UO0Qe6QQQ                vibes      0
# 14  6rBsMLsM5ZvoXwwhDzFtiu                Guilt      0
# 15  22sPO459sq8IRrrldgtYlK               Island      0
# 16  5t7IzFdUp4JGLnyXWprlU5                   AB      0

# %%
def getTracks(trackEndpoint,trackAuthToken, playlistID):
    endpoint = trackEndpoint.format(listPlay['id'][playlistID])
    Track_token_headers = {'Authorization':f"Bearer {trackAuthToken}"}
    track_auth_response = requests.get(endpoint,headers = Track_token_headers)
    print('Status Code: ' + str(track_auth_response.status_code))
    track_auth_response_data = track_auth_response.json()
    print('Number of Tracks (capped at 100): '+ str(len(track_auth_response_data['items'])))
    
    
    tracks = []
    artists = []
    playlist_name = listPlay['playlists'][playlistID]
    playlist_id = listPlay['id'][playlistID]
    
    
    for i in range(len(track_auth_response_data['items'])):
        tracks.append(track_auth_response_data['items'][i]['track']['name'])
        artists.append(track_auth_response_data['items'][i]['track']['artists'][0]['name'])
        
    d = {'tracks':tracks,'artists':artists, 'Playlist':playlist_name,'id':playlist_id}
    df_tracks = pd.DataFrame(data = d)
    
    return df_tracks

# %%
trackList = getTracks(track_endpoint, tracks_OAuth,5)
# Out:
# Status Code: 200
# Number of Tracks (capped at 100): 41

# %%
trackList
# Out:
#                                                tracks          artists  \
# 0                   Just Good Friends - 2012 Remaster  Michael Jackson
# 1                      Leave Me Alone - 2012 Remaster  Michael Jackson
# 2                      You Rock My World - Radio Edit  Michael Jackson
# 3                      Don't Stop 'Til You Get Enough  Michael Jackson
# 4                      Rock with You - Single Version  Michael Jackson
# 5                               Workin' Day and Night  Michael Jackson
# 6                                    Get on the Floor  Michael Jackson
# 7                                        Baby Be Mine  Michael Jackson
# 8                                            Thriller  Michael Jackson
# 9                                             Beat It  Michael Jackson
# 10                                        Billie Jean  Michael Jackson
# 11                                       Human Nature  Michael Jackson
# 12                        P.Y.T. (Pretty Young Thing)  Michael Jackson
# 13                                Slave to the Rhythm  Michael Jackson
# 14                                       Off the Wall  Michael Jackson
# 15                                Bad - 2012 Remaster  Michael Jackson
# 16           The Way You Make Me Feel - 2012 Remaster  Michael Jackson
# 17                        Wanna Be Startin' Somethin'  Michael Jackson
# 18  Wanna Be Startin' Somethin' 2008 with Akon (wi...  Michael Jackson
# 19                 Another Part of Me - 2012 Remaster  Michael Jackson
# 20                  Man in the Mirror - 2012 Remaster  Michael Jackson
# 21                        Dirty Diana - 2012 Remaster  Michael Jackson
# 22                    Smooth Criminal - 2012 Remaster  Michael Jackson
# 23                                  Remember the Time  Michael Jackson
# 24                                     Black or White  Michael Jackson
# 25                           They Don't Care About Us  Michael Jackson
# 26                                  You Are Not Alone  Michael Jackson
# 27                                     Tabloid Junkie  Michael Jackson
# 28                           Why You Wanna Trip on Me  Michael Jackson
# 29                                  You Rock My World  Michael Jackson
# 30                                         Invincible  Michael Jackson
# 31                                    Heaven Can Wait  Michael Jackson
# 32         This Place Hotel (a.k.a. Heartbreak Hotel)     The Jacksons
# 33                                          Dangerous  Michael Jackson
# 34                                   Whatever Happens  Michael Jackson
# 35  I Just Can't Stop Loving You (feat. Siedah Gar...  Michael Jackson
# 36            Liberian Girl - 2012 Remastered Version  Michael Jackson
# 37         This Place Hotel (a.k.a. Heartbreak Hotel)     The Jacksons
# 38                                    Can You Feel It     The Jacksons
# 39  Shake Your Body (Down to the Ground) - 7" Version     The Jacksons
# 40              She's Out of My Life - Single Version  Michael Jackson
#
#    Playlist                      id
# 0        MJ  7DusX2liW1lemQzgjMGy2N
# 1        MJ  7DusX2liW1lemQzgjMGy2N
# 2        MJ  7DusX2liW1lemQzgjMGy2N
# 3        MJ  7DusX2liW1lemQzgjMGy2N
# 4        MJ  7DusX2liW1lemQzgjMGy2N
# 5        MJ  7DusX2liW1lemQzgjMGy2N
# 6        MJ  7DusX2liW1lemQzgjMGy2N
# 7        MJ  7DusX2liW1lemQzgjMGy2N
# 8        MJ  7DusX2liW1lemQzgjMGy2N
# 9        MJ  7DusX2liW1lemQzgjMGy2N
# 10       MJ  7DusX2liW1lemQzgjMGy2N
# 11       MJ  7DusX2liW1lemQzgjMGy2N
# 12       MJ  7DusX2liW1lemQzgjMGy2N
# 13       MJ  7DusX2liW1lemQzgjMGy2N
# 14       MJ  7DusX2liW1lemQzgjMGy2N
# 15       MJ  7DusX2liW1lemQzgjMGy2N
# 16       MJ  7DusX2liW1lemQzgjMGy2N
# 17       MJ  7DusX2liW1lemQzgjMGy2N
# 18       MJ  7DusX2liW1lemQzgjMGy2N
# 19       MJ  7DusX2liW1lemQzgjMGy2N
# 20       MJ  7DusX2liW1lemQzgjMGy2N
# 21       MJ  7DusX2liW1lemQzgjMGy2N
# 22       MJ  7DusX2liW1lemQzgjMGy2N
# 23       MJ  7DusX2liW1lemQzgjMGy2N
# 24       MJ  7DusX2liW1lemQzgjMGy2N
# 25       MJ  7DusX2liW1lemQzgjMGy2N
# 26       MJ  7DusX2liW1lemQzgjMGy2N
# 27       MJ  7DusX2liW1lemQzgjMGy2N
# 28       MJ  7DusX2liW1lemQzgjMGy2N
# 29       MJ  7DusX2liW1lemQzgjMGy2N
# 30       MJ  7DusX2liW1lemQzgjMGy2N
# 31       MJ  7DusX2liW1lemQzgjMGy2N
# 32       MJ  7DusX2liW1lemQzgjMGy2N
# 33       MJ  7DusX2liW1lemQzgjMGy2N
# 34       MJ  7DusX2liW1lemQzgjMGy2N
# 35       MJ  7DusX2liW1lemQzgjMGy2N
# 36       MJ  7DusX2liW1lemQzgjMGy2N
# 37       MJ  7DusX2liW1lemQzgjMGy2N
# 38       MJ  7DusX2liW1lemQzgjMGy2N
# 39       MJ  7DusX2liW1lemQzgjMGy2N
# 40       MJ  7DusX2liW1lemQzgjMGy2N
